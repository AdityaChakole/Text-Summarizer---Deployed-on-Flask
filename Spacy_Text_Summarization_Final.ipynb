# %% [markdown]
# Text Summarizer usign Spacy

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
cctext="""Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.
The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.
The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.
Researchers named the new species the Tapanuli orangutan. They say the animals are considered a new species because of genetic, skeletal and tooth differences.
Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years. He said he was excited to be part of the unusual discovery of a new great ape in the present day. He noted that most great apes are currently considered endangered or severely endangered.
Gorillas, chimpanzees and bonobos also belong to the great ape species.
Orangutan – which means person of the forest in the Indonesian and Malay languages - is the world’s biggest tree-living mammal. The orange-haired animals can move easily among the trees because their arms are longer than their legs. They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest.
The new study said fewer than 800 of the newly-described orangutans exist. Their low numbers make the group the most endangered of all the great ape species.
They live within an area covering about 1,000 square kilometers. The population is considered highly vulnerable. That is because the environment which they depend on is greatly threatened by development.
Researchers say if steps are not taken quickly to reduce the current and future threats, the new species could become extinct “within our lifetime.”
Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species. The adult male orangutan had been beaten by local villagers and died of his injuries. The complete skull was examined by researchers.
Among the physical differences of the new species are a notably smaller head and frizzier hair. The Tapanuli orangutans also have a different diet and are found only in higher forest areas.
There is no unified international system for recognizing new species. But to be considered, discovery claims at least require publication in a major scientific publication.
Russell Mittermeier is head of the primate specialist group at the International Union for the Conservation of Nature. He called the finding a “remarkable discovery.” He said it puts responsibility on the Indonesian government to help the species survive.
Matthew Nowak is one of the writers of the study. He told the Associated Press that there are three groups of the Tapanuli orangutans that are separated by non-protected land.He said forest land needs to connect the separated groups.
In addition, the writers of the study are recommending that plans for a hydropower center in the area be stopped by the government.
It also recommended that remaining forest in the Sumatran area where the orangutans live be protected.
I’m Bryan Lynn.
"""

# %%
# import spacy
# nlp = spacy.load('en_core_web_sm')

#importing the large spacy library

import spacy.cli
spacy.cli.download("en_core_web_lg")
nlp = spacy.load('en_core_web_lg')

from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# lemmetization using spacy
ctt=nlp(cctext)

empty_list = []
for token in ctt:
    empty_list.append(token.lemma_)

final_string = ' '.join(map(str,empty_list))
print(final_string)
# Out:
# scientist say they have discover a new specie of orangutan on Indonesia ’s island of Sumatra .
#  the population differ in several way from the two exist orangutan specie find in Sumatra and the neighbor island of Borneo .
#  the orangutan be find inside North Sumatra ’s Batang Toru forest , the science publication Current Biology report .
#  researcher name the new specie the Tapanuli orangutan . they say the animal be consider a new specie because of genetic , skeletal and tooth difference .
#  Michael Kruetzen be a geneticist with the University of Zurich who have study the orangutan for several year . he say he be excited to be part of the unusual discovery of a new great ape in the present day . he note that most great ape be currently consider endangered or severely endanger .
#  gorilla , chimpanzee and bonobo also belong to the great ape specie .
# ...

# %%
# tokenize ctext
ct=nlp(final_string)
ct_tokens=[i.text for i in ct]

ct_tokens
# Out:
# ['scientist',
#  'say',
#  'they',
#  'have',
#  'discover',
#  'a',
#  'new',
#  'specie',
#  'of',
#  'orangutan',
#  'on',
#  'Indonesia',
#  '’s',
#  'island',
#  'of',
#  'Sumatra',
#  '.',
#  '\n ',
#  'the',
#  'population',
#  'differ',
#  'in',
#  'several',
#  'way',
#  'from',
#  'the',
#  'two',
#  'exist',
#  'orangutan',
#  'specie',
#  'find',
#  'in',
#  'Sumatra',
#  'and',
#  'the',
#  'neighbor',
#  'island',
#  'of',
#  'Borneo',
#  '.',
#  '\n ',
#  'the',
#  'orangutan',
#  'be',
#  'find',
#  'inside',
#  'North',
#  'Sumatra',
#  '’s',
#  'Batang',
#  'Toru',
#  'forest',
#  ',',
#  'the',
#  'science',
#  'publication',
#  'Current',
#  'Biology',
#  'report',
#  '.',
#  '\n ',
#  'researcher',
#  'name',
#  'the',
#  'new',
#  'specie',
#  'the',
#  'Tapanuli',
#  'orangutan',
#  '.',
#  'they',
#  'say',
#  'the',
#  'animal',
#  'be',
#  'consider',
#  'a',
#  'new',
#  'specie',
#  'because',
#  'of',
#  'genetic',
#  ',',
#  'skeletal',
#  'and',
# ...

# %%
# removing punctuations which are also a part of token right now
#print(punctuation) # gives the list of punctuations

print(punctuation)
punctuation1=punctuation+"\n" +"\n "
punctuation1
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n\n '

# %%
##removing stop words from ctext and calculating word frequency

ct_word_frequencies={}
for w1 in ct_tokens:
   
    if w1.lower() not in STOP_WORDS:
      if w1.lower() not in punctuation1:
        if w1.lower()!= "\n ": # the \n is not included in stop words or puntuation
          if w1 not in ct_word_frequencies.keys():
            ct_word_frequencies[w1]=1
          else:
            ct_word_frequencies[w1] +=1

ct_word_frequencies
# Out:
# {'scientist': 1,
#  'discover': 1,
#  'new': 9,
#  'specie': 12,
#  'orangutan': 11,
#  'Indonesia': 1,
#  'island': 2,
#  'Sumatra': 4,
#  'population': 2,
#  'differ': 1,
#  'way': 1,
#  'exist': 2,
#  'find': 4,
#  'neighbor': 1,
#  'Borneo': 1,
#  'inside': 1,
#  'North': 1,
#  'Batang': 1,
#  'Toru': 1,
#  'forest': 6,
#  'science': 1,
#  'publication': 3,
#  'Current': 1,
#  'Biology': 1,
#  'report': 1,
#  'researcher': 3,
#  'Tapanuli': 3,
#  'animal': 2,
#  'consider': 4,
#  'genetic': 1,
#  'skeletal': 1,
#  'tooth': 1,
#  'difference': 2,
#  'Michael': 1,
#  'Kruetzen': 1,
#  'geneticist': 1,
#  'University': 1,
#  'Zurich': 1,
#  'study': 4,
#  'year': 1,
#  'excited': 1,
#  'unusual': 1,
#  'discovery': 3,
#  'great': 5,
#  'ape': 5,
#  'present': 1,
#  'day': 1,
#  'note': 1,
#  'currently': 1,
#  'endangered': 2,
#  'severely': 1,
#  'endanger': 1,
#  'gorilla': 1,
#  'chimpanzee': 1,
#  'bonobo': 1,
#  'belong': 1,
#  'Orangutan': 1,
#  '–': 1,
#  'mean': 1,
# ...

# %%
# similarly, from the ctext, we extract NER and put it as list
NER_list=[e.text for e in ct.ents]
NER_list
# Out:
# ['Indonesia',
#  'Sumatra',
#  'two',
#  'Sumatra',
#  'Borneo',
#  'North Sumatra',
#  'Batang Toru',
#  'Current Biology',
#  'Michael Kruetzen',
#  'the University of Zurich',
#  'several year',
#  'indonesian',
#  'Malay',
#  'few than 800',
#  'about 1,000 square kilometer',
#  '2013',
#  'Sumatra',
#  'Russell Mittermeier',
#  'the International Union for the Conservation of Nature',
#  'indonesian',
#  'Matthew Nowak',
#  'one',
#  'the Associated Press',
#  'three',
#  'Tapanuli',
#  'Bryan Lynn']

# %%
from collections import Counter

d1 = Counter(NER_list)

d1
# Out:
# Counter({'Indonesia': 1,
#          'Sumatra': 3,
#          'two': 1,
#          'Borneo': 1,
#          'North Sumatra': 1,
#          'Batang Toru': 1,
#          'Current Biology': 1,
#          'Michael Kruetzen': 1,
#          'the University of Zurich': 1,
#          'several year': 1,
#          'indonesian': 2,
#          'Malay': 1,
#          'few than 800': 1,
#          'about 1,000 square kilometer': 1,
#          '2013': 1,
#          'Russell Mittermeier': 1,
#          'the International Union for the Conservation of Nature': 1,
#          'Matthew Nowak': 1,
#          'one': 1,
#          'the Associated Press': 1,
#          'three': 1,
#          'Tapanuli': 1,
#          'Bryan Lynn': 1})

# %%
# # # Now we need to add these NER to the dictionary , increase the value by their count if word is already in the dictionary, otherwise add the word and make its value as max frequency, since they need to be given higher weightage as they are NER
# # the more the number of times that NER is present in the text, the more weightage to it


for k,v in d1.items():
  if k in ct_word_frequencies.keys():
    ct_word_frequencies[k]+=v 
  else:
    ct_word_frequencies.update({k:max(ct_word_frequencies.values())})

# %%
ct_word_frequencies
# Out:
# {'scientist': 1,
#  'discover': 1,
#  'new': 9,
#  'specie': 12,
#  'orangutan': 11,
#  'Indonesia': 3,
#  'island': 2,
#  'Sumatra': 10,
#  'population': 2,
#  'differ': 1,
#  'way': 1,
#  'exist': 2,
#  'find': 4,
#  'neighbor': 1,
#  'Borneo': 3,
#  'inside': 1,
#  'North': 1,
#  'Batang': 1,
#  'Toru': 1,
#  'forest': 6,
#  'science': 1,
#  'publication': 3,
#  'Current': 1,
#  'Biology': 1,
#  'report': 1,
#  'researcher': 3,
#  'Tapanuli': 5,
#  'animal': 2,
#  'consider': 4,
#  'genetic': 1,
#  'skeletal': 1,
#  'tooth': 1,
#  'difference': 2,
#  'Michael': 1,
#  'Kruetzen': 1,
#  'geneticist': 1,
#  'University': 1,
#  'Zurich': 1,
#  'study': 4,
#  'year': 1,
#  'excited': 1,
#  'unusual': 1,
#  'discovery': 3,
#  'great': 5,
#  'ape': 5,
#  'present': 1,
#  'day': 1,
#  'note': 1,
#  'currently': 1,
#  'endangered': 2,
#  'severely': 1,
#  'endanger': 1,
#  'gorilla': 1,
#  'chimpanzee': 1,
#  'bonobo': 1,
#  'belong': 1,
#  'Orangutan': 1,
#  '–': 1,
#  'mean': 1,
# ...

# %%
# hl_max_freq=max(hl_word_frequencies.values())
# hl_max_freq

# %%
ct_max_freq=max(ct_word_frequencies.values())
ct_max_freq
# Out:
# 13

# %%
#normalized frequency of each word in text(weighted frequency)

for k in ct_word_frequencies.keys():
  ct_word_frequencies[k]=ct_word_frequencies[k]/ct_max_freq

# %%
ct_word_frequencies
# Out:
# {'scientist': 0.08333333333333333,
#  'discover': 0.08333333333333333,
#  'new': 0.75,
#  'specie': 1.0,
#  'orangutan': 0.9166666666666666,
#  'Indonesia': 0.16666666666666666,
#  'island': 0.16666666666666666,
#  'Sumatra': 0.5833333333333334,
#  'population': 0.16666666666666666,
#  'differ': 0.08333333333333333,
#  'way': 0.08333333333333333,
#  'exist': 0.16666666666666666,
#  'find': 0.3333333333333333,
#  'neighbor': 0.08333333333333333,
#  'Borneo': 0.16666666666666666,
#  'inside': 0.08333333333333333,
#  'North': 0.08333333333333333,
#  'Batang': 0.08333333333333333,
#  'Toru': 0.08333333333333333,
#  'forest': 0.5,
#  'science': 0.08333333333333333,
#  'publication': 0.25,
#  'Current': 0.08333333333333333,
#  'Biology': 0.08333333333333333,
#  'report': 0.08333333333333333,
#  'researcher': 0.25,
#  'Tapanuli': 0.3333333333333333,
#  'animal': 0.16666666666666666,
#  'consider': 0.3333333333333333,
#  'genetic': 0.08333333333333333,
#  'skeletal': 0.08333333333333333,
# ...

# %%
len(ct_word_frequencies)
# Out:
# 198

# %% [markdown]
# Tokenize over sentence in Spacy

# %%
sentence_token= [k for k in ctt.sents]
print(sentence_token)
# Out:
# [Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.
# , The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.
# , The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.
# , Researchers named the new species the Tapanuli orangutan., They say the animals are considered a new species because of genetic, skeletal and tooth differences.
# , Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years., He said he was excited to be part of the unusual discovery of a new great ape in the present day., He noted that most great apes are currently considered endangered or severely endangered.
# , Gorillas, chimpanzees and bonobos also belong to the great ape species.
# ...

# %%
len(sentence_token)
# Out:
# 33

# %%
# the sentence are scored based on the presence of keywords in them
sentence_score={}
for sent in sentence_token:
  for word in sent:
     if word.text.lower() in ct_word_frequencies.keys():
       if sent not in sentence_score.keys():
         sentence_score[sent]=ct_word_frequencies[word.text.lower()]
       else:
         sentence_score[sent]+= ct_word_frequencies[word.text.lower()]

# %%
sentence_score
# Out:
# {Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.: 1.0,
#  The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 2.25,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 1.0833333333333333,
#  Researchers named the new species the Tapanuli orangutan.: 1.6666666666666665,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 1.0,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.16666666666666666,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 2.166666666666667,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.9166666666666666,
# ...

# %%
#Removing the redundant sentences, based on Similarity scores
# the first sentence will be taken as reference, and other sentences showing higher similarity to that will be removed
# this needs spacy large dictionary

ref_sent = sentence_token[0]
other_sent = sentence_token[1:]
similarity_score = np.zeros(len(other_sent)) # initially an array of length is defined which will have all zero values
for i, doc in enumerate(other_sent):
    similarity_score[i] = ref_sent.similarity(doc)

# %%
similarity_score # this is between 1st sentence and other sentences , because 1st sentence will anyways be there in the summary
# Out:
# array([0.84345955, 0.81356376, 0.83182389, 0.88886279, 0.85070032,
#        0.84479463, 0.73427474, 0.79036492, 0.86500996, 0.73574954,
#        0.84382731, 0.82922721, 0.86951739, 0.67464125, 0.73464388,
#        0.79865754, 0.82869679, 0.74396706, 0.64618391, 0.8835597 ,
#        0.83979279, 0.78146392, 0.79159904, 0.82327712, 0.66203028,
#        0.76282251, 0.86497611, 0.79364097, 0.71606559, 0.82855451,
#        0.77782768, 0.02140034])

# %%
#finding the similarity amongst all sentences with each other
# for i in sentence_token:
#   for j in sentence_token:
#     print(i.text,j.text,i.similarity(j))

# %%
#creating dictionary {sentence:similarity score}, the 1st sentence is not taken
sentence_similarity = {sentence_token[1:][i]: similarity_score[i] for i in range(len(sentence_token[1:]))}
sentence_similarity
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 0.8434595465660095,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 0.8135637640953064,
#  Researchers named the new species the Tapanuli orangutan.: 0.8318238854408264,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 0.8888627886772156,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.850700318813324,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 0.8447946310043335,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.7342747449874878,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.7903649210929871,
# ...

# %%
#removing sentences showing 90% similarity to remove redundancy
sentence_simi={}
for i,j in sentence_similarity.items():
  if j<=0.90:
    sentence_simi.update({i:j})
sentence_simi
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 0.8434595465660095,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 0.8135637640953064,
#  Researchers named the new species the Tapanuli orangutan.: 0.8318238854408264,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 0.8888627886772156,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.850700318813324,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 0.8447946310043335,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.7342747449874878,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.7903649210929871,
# ...

# %%
#creating dictionary {final sentences to be taken:sentence score}, the 1st sentence is not taken
final_list={}
for i in sentence_simi.keys():
  for k,v in sentence_score.items():
    if i==k:
      final_list.update({i:v})

# %%
final_list
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 2.25,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 1.0833333333333333,
#  Researchers named the new species the Tapanuli orangutan.: 1.6666666666666665,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 1.0,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.16666666666666666,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 2.166666666666667,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.9166666666666666,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.9166666666666667,
# ...

# %%
from heapq import nlargest # nlargest will help us select the sentences with largest scores

# %%
# we will take the 30% of the original text length as the summary length
summ_length=int(len(sentence_token)*0.30)
summ_length
# Out:
# 9

# %%
summary_1=nlargest(summ_length,final_list,key=final_list.get)

# %%
summary_2=[sentence_token[0]] + summary_1 # the 1st sentence is to be always added in the summary directly as it is in the beginning of the text with important information
summary_2
# Out:
# [Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.,
#  Researchers say if steps are not taken quickly to reduce the current and future threats, the new species could become extinct “within our lifetime.”
#  Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species.,
#  The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.,
#  Orangutan – which means person of the forest in the Indonesian and Malay languages - is the world’s biggest tree-living mammal.,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.,
#  Researchers named the new species the Tapanuli orangutan.,
#  They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest.,
# ...

# %%
final_summary=[word.text for word in summary_2]

# %%
summary=" ".join(final_summary)

# %%
print(summary)
# Out:
# Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.
#  Researchers say if steps are not taken quickly to reduce the current and future threats, the new species could become extinct “within our lifetime.”
# Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species. The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.
#  Orangutan – which means person of the forest in the Indonesian and Malay languages - is the world’s biggest tree-living mammal. He said he was excited to be part of the unusual discovery of a new great ape in the present day. Researchers named the new species the Tapanuli orangutan. They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest.
# ...

# %%
#performing data cleansing by RE which may improve the results

# %%
import re

#Removes non-alphabetic characters:
def text_strip(doc):
    
        
        #ORDER OF REGEX IS VERY VERY IMPORTANT!!!!!!
        
        doc=re.sub("(\\t)", ' ', str(doc)) #remove escape characters
        doc=re.sub("(\\r)", ' ', str(doc)) 
        doc=re.sub("(\\n)", ' ', str(doc))
        
        doc=re.sub("(__+)", ' ', str(doc))   #remove _ if it occors more than one time consecutively
        doc=re.sub("(--+)", ' ', str(doc))   #remove - if it occors more than one time consecutively
        doc=re.sub("(~~+)", ' ', str(doc))   #remove ~ if it occors more than one time consecutively
        doc=re.sub("(\+\++)", ' ', str(doc))   #remove + if it occors more than one time consecutively
        doc=re.sub("(\.\.+)", ' ', str(doc))   #remove . if it occors more than one time consecutively
                
        #doc=re.sub("(\.\s+)", ' ', str(doc)) #remove full stop at end of words(not between)
        doc=re.sub("(\-\s+)", ' ', str(doc)) #remove - at end of words(not between)
        doc=re.sub("(\:\s+)", ' ', str(doc)) #remove : at end of words(not between)
        
        try:
            url_id = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(doc))
            repl_url = url_id.group(3)
            doc = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)',repl_url, str(doc))
        except:
            pass #there might be emails with no url in them
      
        
        doc = re.sub("(\s+)",' ',str(doc)) #remove multiple spaces
              
        
        return doc

# %%
# data first cleaned through regular expressions

clean_text = text_strip(cctext)
clean_text
# Out:
# 'Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra. The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo. The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported. Researchers named the new species the Tapanuli orangutan. They say the animals are considered a new species because of genetic, skeletal and tooth differences. Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years. He said he was excited to be part of the unusual discovery of a new great ape in the present day. He noted that most great apes are currently considered endangered or severely endangered. Gorillas, chimpanzees and bonobos also belong to the great ape species. Orangutan – which means person of the forest in the Indonesian and Malay languages is the world’s biggest tree-li
# ...

# %%
# lemmetization using spacy
re_ctt=nlp(clean_text)

empty_list = []
for token in re_ctt:
    empty_list.append(token.lemma_)

re_final_string = ' '.join(map(str,empty_list))
re_final_string
# Out:
# 'scientist say they have discover a new specie of orangutan on Indonesia ’s island of Sumatra . the population differ in several way from the two exist orangutan specie find in Sumatra and the neighbor island of Borneo . the orangutan be find inside North Sumatra ’s Batang Toru forest , the science publication Current Biology report . researcher name the new specie the Tapanuli orangutan . they say the animal be consider a new specie because of genetic , skeletal and tooth difference . Michael Kruetzen be a geneticist with the University of Zurich who have study the orangutan for several year . he say he be excited to be part of the unusual discovery of a new great ape in the present day . he note that most great ape be currently consider endangered or severely endanger . gorilla , chimpanzee and bonobo also belong to the great ape specie . Orangutan – which mean person of the forest in the indonesian and Malay language be the world ’s big tree - live mammal . the orange - haired ani
# ...

# %%
# tokenize ctext
re_ct=nlp(re_final_string)
re_ct_tokens=[i.text for i in re_ct]

#re_ct_tokens=[i.text for i in nlp(text_strip(ctext))]

re_ct_tokens
# Out:
# ['scientist',
#  'say',
#  'they',
#  'have',
#  'discover',
#  'a',
#  'new',
#  'specie',
#  'of',
#  'orangutan',
#  'on',
#  'Indonesia',
#  '’s',
#  'island',
#  'of',
#  'Sumatra',
#  '.',
#  'the',
#  'population',
#  'differ',
#  'in',
#  'several',
#  'way',
#  'from',
#  'the',
#  'two',
#  'exist',
#  'orangutan',
#  'specie',
#  'find',
#  'in',
#  'Sumatra',
#  'and',
#  'the',
#  'neighbor',
#  'island',
#  'of',
#  'Borneo',
#  '.',
#  'the',
#  'orangutan',
#  'be',
#  'find',
#  'inside',
#  'North',
#  'Sumatra',
#  '’s',
#  'Batang',
#  'Toru',
#  'forest',
#  ',',
#  'the',
#  'science',
#  'publication',
#  'Current',
#  'Biology',
#  'report',
#  '.',
#  'researcher',
#  'name',
#  'the',
#  'new',
#  'specie',
#  'the',
#  'Tapanuli',
#  'orangutan',
#  '.',
#  'they',
#  'say',
#  'the',
#  'animal',
#  'be',
#  'consider',
#  'a',
#  'new',
#  'specie',
#  'because',
#  'of',
#  'genetic',
#  ',',
#  'skeletal',
#  'and',
#  'tooth',
#  'difference',
#  '.',
# ...

# %%
# similarly, from the ctext, we extract NER and put it as list
# this is also changing as now RE cleaned text is used
re_NER_list=[m.text for m in re_ct.ents]
re_NER_list
# Out:
# ['Indonesia',
#  'Sumatra',
#  'two',
#  'Sumatra',
#  'Borneo',
#  'North Sumatra',
#  'Batang Toru',
#  'Current Biology',
#  'Michael Kruetzen',
#  'the University of Zurich',
#  'several year',
#  'indonesian',
#  'Malay',
#  'few than 800',
#  'about 1,000 square kilometer',
#  '2013',
#  'Sumatra',
#  'Russell Mittermeier',
#  'the International Union for the Conservation of Nature',
#  'indonesian',
#  'Matthew Nowak',
#  'one',
#  'the Associated Press',
#  'three',
#  'Tapanuli',
#  'Bryan Lynn']

# %%
# because the same NER was repeated multiple times in the document
from collections import Counter

d = Counter(re_NER_list)

d
# Out:
# Counter({'Indonesia': 1,
#          'Sumatra': 3,
#          'two': 1,
#          'Borneo': 1,
#          'North Sumatra': 1,
#          'Batang Toru': 1,
#          'Current Biology': 1,
#          'Michael Kruetzen': 1,
#          'the University of Zurich': 1,
#          'several year': 1,
#          'indonesian': 2,
#          'Malay': 1,
#          'few than 800': 1,
#          'about 1,000 square kilometer': 1,
#          '2013': 1,
#          'Russell Mittermeier': 1,
#          'the International Union for the Conservation of Nature': 1,
#          'Matthew Nowak': 1,
#          'one': 1,
#          'the Associated Press': 1,
#          'three': 1,
#          'Tapanuli': 1,
#          'Bryan Lynn': 1})

# %%
##removing stop words from ctext and calculating word frequency

re_ct_word_frequencies={}
for w1 in re_ct_tokens:
   
    if w1.lower() not in STOP_WORDS:
      if w1.lower() not in punctuation1:
        if w1.lower() != "\n ": # the \n is not included in stop words or puntuation
         if w1 not in re_ct_word_frequencies.keys():
           re_ct_word_frequencies[w1]=1
         else:
           re_ct_word_frequencies[w1] +=1

re_ct_word_frequencies
# Out:
# {'scientist': 1,
#  'discover': 1,
#  'new': 9,
#  'specie': 12,
#  'orangutan': 11,
#  'Indonesia': 1,
#  'island': 2,
#  'Sumatra': 4,
#  'population': 2,
#  'differ': 1,
#  'way': 1,
#  'exist': 2,
#  'find': 4,
#  'neighbor': 1,
#  'Borneo': 1,
#  'inside': 1,
#  'North': 1,
#  'Batang': 1,
#  'Toru': 1,
#  'forest': 6,
#  'science': 1,
#  'publication': 3,
#  'Current': 1,
#  'Biology': 1,
#  'report': 1,
#  'researcher': 3,
#  'Tapanuli': 3,
#  'animal': 2,
#  'consider': 4,
#  'genetic': 1,
#  'skeletal': 1,
#  'tooth': 1,
#  'difference': 2,
#  'Michael': 1,
#  'Kruetzen': 1,
#  'geneticist': 1,
#  'University': 1,
#  'Zurich': 1,
#  'study': 4,
#  'year': 1,
#  'excited': 1,
#  'unusual': 1,
#  'discovery': 3,
#  'great': 5,
#  'ape': 5,
#  'present': 1,
#  'day': 1,
#  'note': 1,
#  'currently': 1,
#  'endangered': 2,
#  'severely': 1,
#  'endanger': 1,
#  'gorilla': 1,
#  'chimpanzee': 1,
#  'bonobo': 1,
#  'belong': 1,
#  'Orangutan': 1,
#  '–': 1,
#  'mean': 1,
# ...

# %%
# # Now we need to add these NER to the dictionary , increase the value by 1 if word is already in the dictionary
# the more the number of times that NER is present in the text, the more weightage to it

for k,v in d.items():
  if k in re_ct_word_frequencies.keys():
    re_ct_word_frequencies[k]+=v
  else:
    re_ct_word_frequencies.update({k:max(re_ct_word_frequencies.values())})

# %%
re_ct_word_frequencies
# Out:
# {'scientist': 1,
#  'discover': 1,
#  'new': 9,
#  'specie': 12,
#  'orangutan': 11,
#  'Indonesia': 2,
#  'island': 2,
#  'Sumatra': 7,
#  'population': 2,
#  'differ': 1,
#  'way': 1,
#  'exist': 2,
#  'find': 4,
#  'neighbor': 1,
#  'Borneo': 2,
#  'inside': 1,
#  'North': 1,
#  'Batang': 1,
#  'Toru': 1,
#  'forest': 6,
#  'science': 1,
#  'publication': 3,
#  'Current': 1,
#  'Biology': 1,
#  'report': 1,
#  'researcher': 3,
#  'Tapanuli': 4,
#  'animal': 2,
#  'consider': 4,
#  'genetic': 1,
#  'skeletal': 1,
#  'tooth': 1,
#  'difference': 2,
#  'Michael': 1,
#  'Kruetzen': 1,
#  'geneticist': 1,
#  'University': 1,
#  'Zurich': 1,
#  'study': 4,
#  'year': 1,
#  'excited': 1,
#  'unusual': 1,
#  'discovery': 3,
#  'great': 5,
#  'ape': 5,
#  'present': 1,
#  'day': 1,
#  'note': 1,
#  'currently': 1,
#  'endangered': 2,
#  'severely': 1,
#  'endanger': 1,
#  'gorilla': 1,
#  'chimpanzee': 1,
#  'bonobo': 1,
#  'belong': 1,
#  'Orangutan': 1,
#  '–': 1,
#  'mean': 1,
# ...

# %%
len(re_ct_word_frequencies) # the length of these tokenized words are slightly different in the conventional cleaning and RE cleaning, so the results might change
# Out:
# 198

# %%
re_ct_max_freq=max(re_ct_word_frequencies.values())
re_ct_max_freq
# Out:
# 12

# %%
#normalized frequency of each word in text(weighted frequency)

for k in re_ct_word_frequencies.keys():
  re_ct_word_frequencies[k]=re_ct_word_frequencies[k]/re_ct_max_freq

# %%
re_ct_word_frequencies
# Out:
# {'scientist': 0.08333333333333333,
#  'discover': 0.08333333333333333,
#  'new': 0.75,
#  'specie': 1.0,
#  'orangutan': 0.9166666666666666,
#  'Indonesia': 0.16666666666666666,
#  'island': 0.16666666666666666,
#  'Sumatra': 0.5833333333333334,
#  'population': 0.16666666666666666,
#  'differ': 0.08333333333333333,
#  'way': 0.08333333333333333,
#  'exist': 0.16666666666666666,
#  'find': 0.3333333333333333,
#  'neighbor': 0.08333333333333333,
#  'Borneo': 0.16666666666666666,
#  'inside': 0.08333333333333333,
#  'North': 0.08333333333333333,
#  'Batang': 0.08333333333333333,
#  'Toru': 0.08333333333333333,
#  'forest': 0.5,
#  'science': 0.08333333333333333,
#  'publication': 0.25,
#  'Current': 0.08333333333333333,
#  'Biology': 0.08333333333333333,
#  'report': 0.08333333333333333,
#  'researcher': 0.25,
#  'Tapanuli': 0.3333333333333333,
#  'animal': 0.16666666666666666,
#  'consider': 0.3333333333333333,
#  'genetic': 0.08333333333333333,
#  'skeletal': 0.08333333333333333,
# ...

# %% [markdown]
# Tokenize over sentence using Spacy

# %%
re_sentence_token= [k for k in re_ctt.sents]
re_sentence_token
# Out:
# [Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.,
#  The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.,
#  Researchers named the new species the Tapanuli orangutan.,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.,
#  He noted that most great apes are currently considered endangered or severely endangered.,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.,
# ...

# %%
len(re_sentence_token) # this length is different in previous case
# Out:
# 34

# %%
# the sentence are scored based on the presence of keywords in them
re_sentence_score={}
for sent in re_sentence_token:
  for word in sent:
     if word.text.lower() in re_ct_word_frequencies.keys():
       if sent not in re_sentence_score.keys():
         re_sentence_score[sent]=re_ct_word_frequencies[word.text.lower()]
       else:
         re_sentence_score[sent]+= re_ct_word_frequencies[word.text.lower()]

# %%
re_sentence_score # these values are different from previous values
# Out:
# {Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.: 1.0,
#  The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 2.25,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 1.0833333333333333,
#  Researchers named the new species the Tapanuli orangutan.: 1.6666666666666665,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 1.0,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.16666666666666666,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 2.166666666666667,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.9166666666666666,
# ...

# %%
#Removing the redundant sentences, based on Similarity scores
# the first sentence will be taken as refernce, and other sentences showing higher similarity to that will be removed
# this needs spacy large dictionary

re_ref_sent = re_sentence_token[0]
re_other_sent = re_sentence_token[1:]
re_similarity_score = np.zeros(len(re_other_sent))
for i, doc in enumerate(re_other_sent):
    re_similarity_score[i] = re_ref_sent.similarity(doc)

# %%
re_similarity_score # these values are different from previous values, there are totally 33 values, since totally there are 34 tokanized sentences and this score is wrt 1st sentence
# Out:
# array([0.84345967, 0.81356376, 0.83182389, 0.88886291, 0.85070038,
#        0.84479475, 0.73427486, 0.79036504, 0.8781898 , 0.7357496 ,
#        0.84382743, 0.82922727, 0.86951745, 0.67464125, 0.734644  ,
#        0.7986576 , 0.77276236, 0.75130081, 0.74396712, 0.64618403,
#        0.88355982, 0.83979279, 0.78146404, 0.79159927, 0.82327724,
#        0.66203028, 0.76282269, 0.86497611, 0.79364097, 0.71606553,
#        0.82855439, 0.7778278 , 0.02140034])

# %%
similarity_score
# Out:
# array([0.84345955, 0.81356376, 0.83182389, 0.88886279, 0.85070032,
#        0.84479463, 0.73427474, 0.79036492, 0.86500996, 0.73574954,
#        0.84382731, 0.82922721, 0.86951739, 0.67464125, 0.73464388,
#        0.79865754, 0.82869679, 0.74396706, 0.64618391, 0.8835597 ,
#        0.83979279, 0.78146392, 0.79159904, 0.82327712, 0.66203028,
#        0.76282251, 0.86497611, 0.79364097, 0.71606559, 0.82855451,
#        0.77782768, 0.02140034])

# %%
re_sentence_similarity = {re_sentence_token[1:][i]: re_similarity_score[i] for i in range(len(re_sentence_token[1:]))}
re_sentence_similarity
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 0.8434596657752991,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 0.8135637640953064,
#  Researchers named the new species the Tapanuli orangutan.: 0.8318238854408264,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 0.8888629078865051,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.8507003784179688,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 0.844794750213623,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.7342748641967773,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.7903650403022766,
# ...

# %%
sentence_similarity
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 0.8434595465660095,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 0.8135637640953064,
#  Researchers named the new species the Tapanuli orangutan.: 0.8318238854408264,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 0.8888627886772156,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.850700318813324,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 0.8447946310043335,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.7342747449874878,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.7903649210929871,
# ...

# %%
#removing sentences showing 90% similarity to remove redundancy
re_sentence_simi={}
for i,j in re_sentence_similarity.items():
  if j<=0.90:
    re_sentence_simi.update({i:j})
re_sentence_simi
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 0.8434596657752991,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 0.8135637640953064,
#  Researchers named the new species the Tapanuli orangutan.: 0.8318238854408264,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 0.8888629078865051,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.8507003784179688,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 0.844794750213623,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.7342748641967773,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.7903650403022766,
# ...

# %%
#creating dictionary {final sentences to be taken:sentence score}, the 1st sentence is not taken
re_final_list={}
for i in re_sentence_simi.keys():
  for k,v in re_sentence_score.items():
    if i==k:
      re_final_list.update({i:v})

# %%
re_final_list
# Out:
# {The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.: 2.25,
#  The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.: 1.0833333333333333,
#  Researchers named the new species the Tapanuli orangutan.: 1.6666666666666665,
#  They say the animals are considered a new species because of genetic, skeletal and tooth differences.: 1.0,
#  Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years.: 0.16666666666666666,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.: 2.166666666666667,
#  He noted that most great apes are currently considered endangered or severely endangered.: 0.9166666666666666,
#  Gorillas, chimpanzees and bonobos also belong to the great ape species.: 0.9166666666666667,
# ...

# %%
from heapq import nlargest # nlargest will help us select the sentences with largest scores

# %%
# we will take the 30% of the original text length as the summary length
re_summ_length=int(len(re_sentence_token)*0.30)
re_summ_length
# Out:
# 10

# %%
re_summary_1=nlargest(re_summ_length,re_final_list,key=re_final_list.get)

# %%
re_summary_1
# Out:
# [Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species.,
#  The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.,
#  Orangutan – which means person of the forest in the Indonesian and Malay languages is the world’s biggest tree-living mammal.,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.,
#  Researchers named the new species the Tapanuli orangutan.,
#  They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest.,
#  Their low numbers make the group the most endangered of all the great ape species.,
#  The new study said fewer than 800 of the newly-described orangutans exist.,
#  It also recommended that remaining forest in the Sumatran area where the orangutans live be protected.,
# ...

# %%
re_summary_2=[re_sentence_token[0]] + re_summary_1 # the 1st sentence is to be always added in the summary directly as it is in the beginning of the text with important information
re_summary_2
# Out:
# [Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.,
#  Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species.,
#  The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.,
#  Orangutan – which means person of the forest in the Indonesian and Malay languages is the world’s biggest tree-living mammal.,
#  He said he was excited to be part of the unusual discovery of a new great ape in the present day.,
#  Researchers named the new species the Tapanuli orangutan.,
#  They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest.,
#  Their low numbers make the group the most endangered of all the great ape species.,
#  The new study said fewer than 800 of the newly-described orangutans exist.,
# ...

# %%
re_final_summary=[word.text for word in re_summary_2]

# %%
re_summary=" ".join(re_final_summary)

# %%
re_summary
# Out:
# 'Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra. Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species. The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo. Orangutan – which means person of the forest in the Indonesian and Malay languages is the world’s biggest tree-living mammal. He said he was excited to be part of the unusual discovery of a new great ape in the present day. Researchers named the new species the Tapanuli orangutan. They live more lonely lives than other great apes, spending a lot of time sleeping and eating fruit in the forest. Their low numbers make the group the most endangered of all the great ape species. The new study said fewer than 800 of the newly-described orangutans exist. It also recommended that remaining forest in the
# ...

# %% [markdown]
# Gensim library can also be used to summarize text

# %%
from gensim.summarization.summarizer import summarize

# %%
gensim_summary=summarize(cctext)
gensim_summary
# Out:
# 'The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.\nResearchers named the new species the Tapanuli orangutan.\nThey say the animals are considered a new species because of genetic, skeletal and tooth differences.\nResearch into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species.\nThe Tapanuli orangutans also have a different diet and are found only in higher forest areas.\nIt also recommended that remaining forest in the Sumatran area where the orangutans live be protected.'

# %% [markdown]
# BERT Summarizing

# %%
# !pip install bert-extractive-summarizer==0.7.1
#!pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.9 MB 7.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 42.1 MB/s
# ...
#      |████████████████████████████████| 120 kB 53.2 MB/s
# ...

# %%
from summarizer import Summarizer,TransformerSummarizer
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %% [markdown]
# BERT Summarizer

# %%
bert_model = Summarizer()
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-large-uncased/snapshots/3835a195d41f7ddc47d5ecab84b64f71d6f144e9/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_hidden_states": true,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# ...

# %%
summary_length=int(len(re_sentence_token)*0.30) # here i am using 30% as the 1st sentence will already be added in the summary unlike manual method
summary_length
# Out:
# 10

# %%
#bert_summary=bert_model(ctext, num_sentences=summary_length)

bert_summary = ''.join(bert_model(cctext,num_sentences=summary_length, min_length=60))

print(bert_summary)
# Out:
# Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra. The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported. They say the animals are considered a new species because of genetic, skeletal and tooth differences. He said he was excited to be part of the unusual discovery of a new great ape in the present day. Their low numbers make the group the most endangered of all the great ape species. That is because the environment which they depend on is greatly threatened by development. Research into the new species began in 2013, when an orangutan protection group in Sumatra found an injured orangutan in an area far away from the other species. There is no unified international system for recognizing new species. Russell Mittermeier is head of the primate specialist group at the International Union for the Conservation of Nature. He said it puts responsibility on the Indonesian governm
# ...

# %% [markdown]
# GPT-2 Summarizing

# %%
GPT2_model = TransformerSummarizer(transformer_type="GPT2",transformer_model_key="gpt2-medium")
# Out:
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gpt2-medium/snapshots/e852c9080bc759a01663acf5a828d95b261a9903/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_inner": null,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "output_hidden_states": true,
#   "predict_special_tokens": true,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
# ...

# %%
#GPT2_summary=GPT2_model(ctext,num_sentences=summary_length)

GPT2_summary = ''.join(GPT2_model(cctext, num_sentences=summary_length, min_length=60))
print(GPT2_summary)
# Out:
# Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra. The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported. He noted that most great apes are currently considered endangered or severely endangered. Gorillas, chimpanzees and bonobos also belong to the great ape species. The orange-haired animals can move easily among the trees because their arms are longer than their legs. They live within an area covering about 1,000 square kilometers. There is no unified international system for recognizing new species. Russell Mittermeier is head of the primate specialist group at the International Union for the Conservation of Nature. He said it puts responsibility on the Indonesian government to help the species survive. He told the Associated Press that there are three groups of the Tapanuli orangutans that are separated by non-protected land. In addition, the writers of the study are rec
# ...

# %% [markdown]
# # XLNet Summarizing

# %%
#XLNet_model = TransformerSummarizer(transformer_type="XLNet",transformer_model_key="xlnet-base-cased")

# %%
#XLNet_summary=XLNet_model(ctext,num_sentences=summary_length)

# XLNet_summary=''.join(XLNet_model(cctext,num_sentences=summary_length,min_length=60))

# print(XLNet_summary)

# %% [markdown]
# Compiling all the results

# %%
print("All Summarizing Results:\n")

print("ORIGINAL TEXT:")
print(cctext)
print("\nSummary after data preprocessing:")
print(summary)
print("\nSummary after data cleansing using RE:")
print(re_summary)
print("\nSummary using Gensim library")
print(gensim_summary)
print("\nBERT Summarizing Result:")
print(bert_summary)
print("\nGPT-2 Summarizing Result:")
print(GPT2_summary)
# print("\nXlNetSummarizing Result:")
# print(XLNet_summary)
# Out:
# All Summarizing Results:
#
# ORIGINAL TEXT:
# Scientists say they have discovered a new species of orangutans on Indonesia’s island of Sumatra.
# The population differs in several ways from the two existing orangutan species found in Sumatra and the neighboring island of Borneo.
# The orangutans were found inside North Sumatra’s Batang Toru forest, the science publication Current Biology reported.
# Researchers named the new species the Tapanuli orangutan. They say the animals are considered a new species because of genetic, skeletal and tooth differences.
# Michael Kruetzen is a geneticist with the University of Zurich who has studied the orangutans for several years. He said he was excited to be part of the unusual discovery of a new great ape in the present day. He noted that most great apes are currently considered endangered or severely endangered.
# Gorillas, chimpanzees and bonobos also belong to the great ape species.
# ...

# %% [markdown]
# Rouge Score

# %% [markdown]
# ROUGE score is the quotient of the matching words under the total count of words in reference sentence.
#
# ROUGE-L — measures longest matching sequence of words using LCS. An advantage of using LCS is that it does not require consecutive matches but in-sequence matches that reflect sentence level word order. Since it automatically includes longest in-sequence common n-grams, you don’t need a predefined n-gram length.
#
#
# recall=No. of matches/ No. of words in reference
#
#
# precision=no. of matches/no. of words in predicted

# %%
# !pip install datasets
from datasets import load_metric
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 365 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 212 kB 56.8 MB/s
# ...
#      |████████████████████████████████| 115 kB 45.6 MB/s
# ...
#      |████████████████████████████████| 127 kB 64.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24955 sha256=78b163dfe3e32fef52497917e9697e5f3dea029c80d21d45375489c66afa4eab
#   Stored in directory: /root/.cache/pip/wheels/84/ac/6b/38096e3c5bf1dc87911e3585875e21a3ac610348e740409c76
# Successfully built rouge-score
# ...

# %%
rouge=load_metric("rouge")

# %%
rs=rouge.compute(predictions=[" The movie was really really good."], references=["The movie was good."])
rs
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8), mid=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8), high=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8)),
#  'rouge2': AggregateScore(low=Score(precision=0.4, recall=0.6666666666666666, fmeasure=0.5), mid=Score(precision=0.4, recall=0.6666666666666666, fmeasure=0.5), high=Score(precision=0.4, recall=0.6666666666666666, fmeasure=0.5)),
#  'rougeL': AggregateScore(low=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8), mid=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8), high=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8), mid=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8), high=Score(precision=0.6666666666666666, recall=1.0, fmeasure=0.8))}

# %%
rs1=rouge.compute(predictions=[" The movie was really really good.The actors have done a great job"], references=["The movie was good.I liked the actors"])
rs1
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.46153846153846156, recall=0.75, fmeasure=0.5714285714285714), mid=Score(precision=0.46153846153846156, recall=0.75, fmeasure=0.5714285714285714), high=Score(precision=0.46153846153846156, recall=0.75, fmeasure=0.5714285714285714)),
#  'rouge2': AggregateScore(low=Score(precision=0.25, recall=0.42857142857142855, fmeasure=0.3157894736842105), mid=Score(precision=0.25, recall=0.42857142857142855, fmeasure=0.3157894736842105), high=Score(precision=0.25, recall=0.42857142857142855, fmeasure=0.3157894736842105)),
#  'rougeL': AggregateScore(low=Score(precision=0.46153846153846156, recall=0.75, fmeasure=0.5714285714285714), mid=Score(precision=0.46153846153846156, recall=0.75, fmeasure=0.5714285714285714), high=Score(precision=0.46153846153846156, recall=0.75, fmeasure=0.5714285714285714)),
# ...

# %%
rouge_score_re_summary_summary=rouge.compute(predictions=["summary"], references=["re_summary"])
rouge_score_re_summary_summary
# Out:
# {'rouge1': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rougeLsum': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666))}

# %%
rouge_score_summary_gensim=rouge.compute(predictions=["summary"], references=["gensim_summary"])
rouge_score_summary_gensim
# Out:
# {'rouge1': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rougeLsum': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666))}

# %%
rouge_score_summary_bert=rouge.compute(predictions=["summary"], references=["bert_summary"])
rouge_score_summary_bert
# Out:
# {'rouge1': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rougeLsum': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666))}

# %%
rouge_score_summary_GPT2=rouge.compute(predictions=["summary"], references=["GPT2_summary"])
rouge_score_summary_GPT2
# Out:
# {'rouge1': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rougeLsum': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666))}

# %%
rouge_score_summary_XLNet=rouge.compute(predictions=["summary"], references=["XLNet_summary"])
rouge_score_summary_XLNet
# Out:
# {'rouge1': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666)),
#  'rougeLsum': AggregateScore(low=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), mid=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666), high=Score(precision=1.0, recall=0.5, fmeasure=0.6666666666666666))}

# %%
rouge_score_GPT2_XLNet=rouge.compute(predictions=["GPT2_summary"], references=["XLNet_summary"])
rouge_score_GPT2_XLNet
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.5, recall=0.5, fmeasure=0.5), mid=Score(precision=0.5, recall=0.5, fmeasure=0.5), high=Score(precision=0.5, recall=0.5, fmeasure=0.5)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=0.5, recall=0.5, fmeasure=0.5), mid=Score(precision=0.5, recall=0.5, fmeasure=0.5), high=Score(precision=0.5, recall=0.5, fmeasure=0.5)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.5, recall=0.5, fmeasure=0.5), mid=Score(precision=0.5, recall=0.5, fmeasure=0.5), high=Score(precision=0.5, recall=0.5, fmeasure=0.5))}

# %%
rouge_score_GPT2_BERT=rouge.compute(predictions=["GPT2_summary"], references=["BERT_summary"])
rouge_score_GPT2_BERT
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.5, recall=0.5, fmeasure=0.5), mid=Score(precision=0.5, recall=0.5, fmeasure=0.5), high=Score(precision=0.5, recall=0.5, fmeasure=0.5)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)),
#  'rougeL': AggregateScore(low=Score(precision=0.5, recall=0.5, fmeasure=0.5), mid=Score(precision=0.5, recall=0.5, fmeasure=0.5), high=Score(precision=0.5, recall=0.5, fmeasure=0.5)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.5, recall=0.5, fmeasure=0.5), mid=Score(precision=0.5, recall=0.5, fmeasure=0.5), high=Score(precision=0.5, recall=0.5, fmeasure=0.5))}
